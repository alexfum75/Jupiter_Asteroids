# %% [markdown]
# ||||||||||||||||
# |:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|:-:|
# ||||||<h1>Jupiter Objects with Python</h1>||||<img src="https://articolidiastronomia.com/wp-content/uploads/2020/08/cropped-orologio-solare.jpg" alt="articolidiastronomia logo" style="height:50px; width:50px;"/>|| [articolidiastronomia.com](attachment:./articolidiastronomia.com) </br> Alessandro Fumagalli|||<img src="https://articolidiastronomia.com/wp-content/uploads/2021/01/licenza.png" alt="licenza" style="height:25px; width:120px;"/>||

# %% [markdown]
# ### Import the modules needed for processing

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Read MPC file with orbital data
# - Data downloaded from https://cgi.minorplanetcenter.net/data

# %%
df = pd.read_csv("data/mpcorb_extended.csv", low_memory=False)
pd.set_option("display.max_columns", None)
df.head()
# Out:
#       H     G  Num_obs   rms  U  Arc_years Perturbers Perturbers_2 Number  \
# 0  3.32  0.15   7259.0  0.65  0  1801-2022        M-v          30l    (1)
# 1  4.12  0.15   8871.0  0.59  0  1804-2022        M-c          28k    (2)
# 2  5.14  0.15   7411.0  0.63  0  1804-2022        M-v          3El    (3)
# 3  3.20  0.15   7508.0  0.63  0  1821-2022        M-p          18l    (4)
# 4  7.02  0.15   3099.0  0.72  0  1845-2022        M-v          3El    (5)
#
#       Name Principal_desig            Other_desigs      Epoch          M  \
# 0    Ceres         A801 AA  ['A899 OF', '1943 XB']  2459800.5  334.32723
# 1   Pallas         A802 FA                     NaN  2459800.5  315.09111
# 2     Juno         A804 RA                     NaN  2459800.5  306.62242
# 3    Vesta         A807 FA                     NaN  2459800.5   61.19232
# 4  Astraea         A845 XA             ['1969 SE']  2459800.5  208.56769
#
#         Peri       Node         i         e         n         a        Ref  \
# 0   73.53158   80.26642  10.58680  0.078636  0.214181  2.766619  E2022-SB7
# 1  310.84262  172.91791  34.92715  0.229986  0.213851  2.769463  MPO710565
# 2  247.80396  169.84591  12.99223  0.256775  0.225857  2.670422  E2022-U28
# 3  151.25772  103.80084   7.14078  0.088402  0.271511  2.361987  E2022-T39
# 4  358.79230  141.56759   5.36542  0.188985  0.238175  2.577540  E2022-U63
#
#    Num_opps  Computer Hex_flags    Last_obs            Tp  Orbital_period  \
# 0       123  MPCLINUX      0000  2022-09-16  2.459920e+06        4.601761
# 1       120  MPCLINUX      0000  2022-08-04  2.460011e+06        4.608859
# 2       113  MPCLINUX      0000  2022-10-16  2.460037e+06        4.363851
# 3       108  MPCLINUX      0000  2022-09-23  2.459575e+06        3.630081
# 4        85  MPCLINUX      0000  2022-10-13  2.460436e+06        4.138168
#
#    Perihelion_dist  Aphelion_dist  Semilatus_rectum  Synodic_period  \
# 0         2.549064       2.984174          1.374756        1.277642
# 1         2.132524       3.406402          1.311488        1.277096
# 2         1.984725       3.356120          1.247176        1.297278
# 3         2.153183       2.570791          1.171764        1.380216
# 4         2.090423       3.064657          1.242741        1.318657
#
#   Orbit_type  NEO_flag  One_km_NEO_flag  PHA_flag  \
# 0        MBA       NaN              NaN       NaN
# 1        MBA       NaN              NaN       NaN
# 2        MBA       NaN              NaN       NaN
# 3        MBA       NaN              NaN       NaN
# 4        MBA       NaN              NaN       NaN
#
#    Critical_list_numbered_object_flag  One_opposition_object_flag  Arc_length
# 0                                 NaN                         NaN         NaN
# 1                                 NaN                         NaN         NaN
# 2                                 NaN                         NaN         NaN
# 3                                 NaN                         NaN         NaN
# 4                                 NaN                         NaN         NaN

# %% [markdown]
# ### Show the size of dataframe in terms of numbers of records found

# %%
df.dropna()
df.shape
# Out:
# (1243630, 38)

# %% [markdown]
# ### Pre processing
# - Removed useless columns
# - Renamed orbit type
# - List all different orbit types

# %%
#removed useless fields and rename others
df.drop(['NEO_flag','Critical_list_numbered_object_flag','One_opposition_object_flag'], axis=1, inplace=True)
df.drop(['One_km_NEO_flag','Computer','Number','U','PHA_flag', 'Hex_flags'], axis=1, inplace=True)
df.drop(['Ref','Arc_length','Tp','Num_opps','Perturbers_2','Perturbers','n'], axis=1, inplace=True)
df.drop(['Semilatus_rectum','Synodic_period','Peri','Node'], axis=1, inplace=True)
df.drop(['Last_obs','Epoch'], axis=1, inplace=True)
df.drop(['Num_obs','rms'], axis=1, inplace=True)

df.rename(columns={"Perihelion_dist": "q", "Aphelion_dist": "Q"}, inplace=True)
df["Orbit_type"].replace({"Object with perihelion distance < 1.665 AU": "q < 1.665 AU"}, inplace=True)
df["Orbit_type"].replace({"Jupiter Trojan": "Trojan"}, inplace=True)
df.Orbit_type.unique()
# Out:
# array(['MBA', 'Phocaea', 'q < 1.665 AU', 'Hilda', 'Amor', 'Hungaria',
#        'Trojan', 'Apollo', 'Distant Object', 'Aten', 'Atira'],
#       dtype=object)

# %% [markdown]
# ### Filter on the following object types:
#
# - Object type $\in$ {Hilda, Trojan, Hungaria}
# - Object with $\sigma$ < 10

# %%
df[['Discover', 'Last_Obs']] = df['Arc_years'].str.split('-', n=1, expand=True)
df.head()
# Out:
#       H     G  Arc_years     Name Principal_desig            Other_desigs  \
# 0  3.32  0.15  1801-2022    Ceres         A801 AA  ['A899 OF', '1943 XB']
# 1  4.12  0.15  1804-2022   Pallas         A802 FA                     NaN
# 2  5.14  0.15  1804-2022     Juno         A804 RA                     NaN
# 3  3.20  0.15  1821-2022    Vesta         A807 FA                     NaN
# 4  7.02  0.15  1845-2022  Astraea         A845 XA             ['1969 SE']
#
#            M         i         e         a  Orbital_period         q  \
# 0  334.32723  10.58680  0.078636  2.766619        4.601761  2.549064
# 1  315.09111  34.92715  0.229986  2.769463        4.608859  2.132524
# 2  306.62242  12.99223  0.256775  2.670422        4.363851  1.984725
# 3   61.19232   7.14078  0.088402  2.361987        3.630081  2.153183
# 4  208.56769   5.36542  0.188985  2.577540        4.138168  2.090423
#
#           Q Orbit_type Discover Last_Obs
# 0  2.984174        MBA     1801     2022
# 1  3.406402        MBA     1804     2022
# 2  3.356120        MBA     1804     2022
# 3  2.570791        MBA     1821     2022
# 4  3.064657        MBA     1845     2022

# %%
MPC_Jupyter_H = df.apply(lambda r: r[df['Orbit_type'].isin(['Hungaria','Hilda','Trojan'])])
MPC_Jupyter_no_outliers = MPC_Jupyter_H[MPC_Jupyter_H['H'] < (10 * MPC_Jupyter_H['H'].std())]

# %% [markdown]
# ## Trojan objects

# %%
MPC_Jupyter_no_outliers_Trojan = MPC_Jupyter_no_outliers[MPC_Jupyter_no_outliers['Orbit_type'] =='Trojan']
MPC_Jupyter_no_outliers_Trojan.head(5)
# Out:
#         H     G  Arc_years       Name Principal_desig            Other_desigs  \
# 587  8.27  0.15  1906-2022   Achilles         A906 DN                     NaN
# 616  8.18  0.15  1906-2022  Patroclus         A906 UL  ['1941 XC', '1962 NB']
# 623  7.45  0.15  1907-2022     Hektor         A907 CF             ['1948 VD']
# 658  8.72  0.15  1908-2022     Nestor         A908 FE             ['A914 WF']
# 883  8.70  0.15  1917-2022    Priamus         A917 SU  ['1929 XX', '1938 KE']
#
#              M         i         e         a  Orbital_period         q  \
# 587  337.91683  10.31992  0.148139  5.209205       11.889323  4.437519
# 616  303.03188  22.06206  0.139868  5.210104       11.892403  4.481378
# 623  271.39649  18.15500  0.022738  5.268938       12.094409  5.149131
# 658   81.65525   4.52244  0.116972  5.167175       11.745724  4.562762
# 883   30.93289   8.90872  0.125238  5.195633       11.842888  4.544944
#
#             Q Orbit_type Discover Last_Obs
# 587  5.980890     Trojan     1906     2022
# 616  5.938830     Trojan     1906     2022
# 623  5.388745     Trojan     1907     2022
# 658  5.771589     Trojan     1908     2022
# 883  5.846321     Trojan     1917     2022

# %% [markdown]
# ### Filter on top 120 Trojan objects

# %%
n_trojan_object = 120
object_list_tot = MPC_Jupyter_no_outliers_Trojan.set_index('Principal_desig').to_dict()['Name']
object_list = {key: value for (key, value) in object_list_tot.items() if not str(value) == 'nan'}
object_list = {A:N for (A,N) in [x for x in object_list.items()][:n_trojan_object]}
main_body = {"Sun" : 'Sun', "Jupiter" : 'Jupiter'}
object_list = {**main_body, **object_list}

# %%
list(object_list.items())[:120]
# Out:
# [('Sun', 'Sun'),
#  ('Jupiter', 'Jupiter'),
#  ('A906 DN', 'Achilles'),
#  ('A906 UL', 'Patroclus'),
#  ('A907 CF', 'Hektor'),
#  ('A908 FE', 'Nestor'),
#  ('A917 SU', 'Priamus'),
#  ('A919 FB', 'Agamemnon'),
#  ('1930 BH', 'Odysseus'),
#  ('1930 UA', 'Aneas'),
#  ('1930 UB', 'Anchises'),
#  ('1931 YA', 'Troilus'),
#  ('1936 QW', 'Ajax'),
#  ('1937 PB', 'Diomedes'),
#  ('1950 SA', 'Antilochus'),
#  ('1957 MK', 'Menelaus'),
#  ('1949 SB', 'Telamon'),
#  ('1971 EA', 'Deiphobus'),
#  ('2008 P-L', 'Thersites'),
#  ('4596 P-L', 'Philoctetes'),
#  ('1971 FE', 'Glaukos'),
#  ('1971 FF', 'Astyanax'),
#  ('1971 FG', 'Helenos'),
#  ('1971 FH', 'Agenor'),
#  ('1976 UQ', 'Stentor'),
#  ('1976 UW', 'Epeios'),
#  ('1977 QH1', 'Antenor'),
#  ('1977 TL3', 'Sarpedon'),
#  ('1979 WM', 'Alcathous'),
#  ('1975 WM1', 'Neoptolemus'),
#  ('1981 AC', 'Phereclos'),
#  ('1977 TJ3', 'Cebriones'),
#  ('1966 BA1', 'Palamedes'),
#  ('1978 TB', 'Acamas'),
#  ('1982 BC3', 'Pandarus'),
#  ('1980 GC', 'Idomeneus'),
#  ('1981 LK', 'Teucer'),
#  ('1975 QD', 'Peiroos'),
#  ('1981 AE1', 'Memnon'),
#  ('1981 JR', 'Automedon'),
#  ('1983 PV', 'Makhaon'),
#  ('1978 VG6', 'Laocoon'),
#  ('1984 KF', 'Paris'),
#  ('1977 DD3', 'Sinon'),
#  ('1984 HA1', 'Mentor'),
#  ('1973 UF5', 'Protesilaos'),
#  ('1973 SO', 'Eurybates'),
#  ('1985 TC1', 'Talthybius'),
#  ('1985 VO', 'Meriones'),
#  ('1974 FV1', 'Socus'),
#  ('1985 TL3', 'Polypoites'),
#  ('1985 TE3', 'Leonteus'),
#  ('1985 TF3', 'Sthenelos'),
#  ('1985 VS', 'Thrasymedes'),
#  ('1973 SR', 'Euryalos'),
#  ('1986 WD', 'Thestor'),
#  ('1985 TQ', 'Demophon'),
#  ('1987 YT1', 'Deipylos'),
#  ('1989 CG2', 'Euforbo'),
#  ('1973 SW', 'Menestheus'),
#  ('1985 VK2', 'Podalirius'),
#  ('1973 SM', 'Kalchas'),
#  ('1988 RU', 'Poulydamas'),
#  ('1988 AK', 'Dracius'),
#  ('1989 CJ3', 'Eurypylos'),
#  ('1989 CQ1', 'Phoinix'),
#  ('1988 PY', 'Khryses'),
#  ('1988 RT', 'Polydoros'),
#  ('1988 TU2', 'Ennomos'),
#  ('1989 TS1', 'Medesicaste'),
#  ('4271 T-3', 'Agelaos'),
#  ('5010 T-3', 'Panthoos'),
#  ('1988 PB1', 'Iphidamas'),
#  ('1988 RK1', 'Lykaon'),
#  ('1990 VH7', 'Asteropaios'),
#  ('1988 QE', 'Dares'),
#  ('1988 RV', 'Misenus'),
#  ('1988 RM1', 'Sergestus'),
#  ('1988 TU1', 'Palinurus'),
#  ('1989 AL2', 'Meges'),
#  ('1989 AM2', 'Thoas'),
#  ('1989 BQ', 'Asaeus'),
#  ('1989 CK1', 'Medon'),
#  ('1989 SZ', 'Polites'),
#  ('1989 AN2', 'Thessandrus'),
#  ('1988 BW1', 'Askalaphus'),
#  ('9507 P-L', 'Eurymedon'),
#  ('1985 TG3', 'Agapenor'),
#  ('1986 TS6', 'Mecisteus'),
#  ('1988 BX1', 'Androgeos'),
#  ('1988 BY1', 'Halaesus'),
#  ('1973 SW1', 'Theotes'),
#  ('1988 RA1', 'Imbrius'),
#  ('1988 TZ1', 'Bitias'),
#  ('1989 BL', 'Cynus'),
#  ('1989 CH2', 'Achaemenides'),
#  ('1989 SC7', 'Ilioneus'),
#  ('1991 XX', 'Achates'),
#  ('1989 CW1', 'Oloosson'),
#  ('1988 RL10', 'Nastes'),
#  ('1973 SQ1', 'Amphilochos'),
#  ('1986 VG1', 'Ulysses'),
#  ('1988 RS10', 'Laogonus'),
#  ('1989 AU1', 'Rhoeo'),
#  ('1989 BB1', 'Epeigeus'),
#  ('1991 KC', 'Telephus'),
#  ('1989 BW', 'Pyrrhus'),
#  ('1989 CK2', 'Orsilocus'),
#  ('1989 EO11', 'Krethon'),
#  ('1990 DK', 'Eumelos'),
#  ('1989 TO11', 'Mulius'),
#  ('1988 TH1', 'Cloanthus'),
#  ('1988 RF1', 'Gyas'),
#  ('1988 TA3', 'Deikoon'),
#  ('1990 VU1', 'Axius'),
#  ('1992 HS3', 'Amphimachus'),
#  ('1989 TU5', 'Rhigmus'),
#  ('1988 RO', 'Eetion'),
#  ('1989 DJ', 'Aulis'),
#  ('1988 RH12', 'Harpalion')]

# %% [markdown]
# ### Plot current orbit snapshot

# %%
import numpy as np
import rebound
import datetime

sim = rebound.Simulation()
sim.units = ['mearth','day','AU']

print(f"*** G: {sim.G}") 

index_obj = 0
missing_mass = []
for jupiter_object, jupiter_name in object_list.items():
    sim.add(jupiter_object)
    print(f"*** Mass of object: {jupiter_name} {sim.particles[index_obj].m} Radius: {sim.particles[index_obj].r}")
    index_obj = index_obj + 1

current_time = datetime.datetime.now()
print("*** Current timestamp is:", current_time)

for i in missing_mass:
    object_list.pop(i)

sim.move_to_com()
#sim.integrator = "ias15"

Jupiter_period = 4330 # Jupiter period
N_output = 433 # number of sample 

# each point is 10 Earth days

x_pos = np.zeros((len(object_list), N_output)) 
y_pos = np.zeros((len(object_list), N_output))
z_pos = np.zeros((len(object_list), N_output))

print(f"*** step: {sim.dt}") 

times = np.linspace(0, Jupiter_period, num = N_output) 

object_index = 0
for jupiter_object, jupiter_name in object_list.items():
    print (f"Integration for object number: {object_index} name: {jupiter_name}")
    for position, t in enumerate (times):
        sim.integrate(t)
        x_pos[object_index, position] = sim.particles[object_index].x
        y_pos[object_index, position] = sim.particles[object_index].y
        z_pos[object_index, position] = sim.particles[object_index].z
    object_index = object_index + 1
# Out:
# *** G: 8.887692445125634e-10
# Searching NASA Horizons for 'Sun'...
# Found: Sun (10)
# *** Mass of object: Sun 332946.0488322924 Radius: 0.0
# Searching NASA Horizons for 'Jupiter'...
# Found: Jupiter Barycenter (5) (chosen from query 'Jupiter')
# *** Mass of object: Jupiter 317.8941938720353 Radius: 0.0
# Searching NASA Horizons for 'A906 DN'...
# Found: 588 Achilles (A906 DN)
# *** Mass of object: Achilles 0.0 Radius: 0.0
# Searching NASA Horizons for 'A906 UL'...
# /home/alfumaga2001/.local/lib/python3.8/site-packages/rebound/horizons.py:168: RuntimeWarning: Warning: Mass cannot be retrieved from NASA HORIZONS. Set to 0.
#   warnings.warn("Warning: Mass cannot be retrieved from NASA HORIZONS. Set to 0.", RuntimeWarning)
# Found: 617 Patroclus (A906 UL)
# *** Mass of object: Patroclus 0.0 Radius: 0.0
# Searching NASA Horizons for 'A907 CF'...
# Found: 624 Hektor (A907 CF)
# *** Mass of object: Hektor 0.0 Radius: 0.0
# Searching NASA Horizons for 'A908 FE'...
# Found: 659 Nestor (A908 FE)
# *** Mass of object: Nestor 0.0 Radius: 0.0
# Searching NASA Horizons for 'A917 SU'...
# Found: 884 Priamus (A917 SU)
# *** Mass of object: Priamus 0.0 Radius: 0.0
# Searching NASA Horizons for 'A919 FB'...
# Found: 911 Agamemnon (A919 FB)
# *** Mass of object: Agamemnon 0.0 Radius: 0.0
# Searching NASA Horizons for '1930 BH'...
# Found: 1143 Odysseus (1930 BH)
# *** Mass of object: Odysseus 0.0 Radius: 0.0
# Searching NASA Horizons for '1930 UA'...
# Found: 1172 Aneas (1930 UA)
# *** Mass of object: Aneas 0.0 Radius: 0.0
# Searching NASA Horizons for '1930 UB'...
# Found: 1173 Anchises (1930 UB)
# *** Mass of object: Anchises 0.0 Radius: 0.0
# Searching NASA Horizons for '1931 YA'...
# Found: 1208 Troilus (1931 YA)
# *** Mass of object: Troilus 0.0 Radius: 0.0
# Searching NASA Horizons for '1936 QW'...
# Found: 1404 Ajax (1936 QW)
# *** Mass of object: Ajax 0.0 Radius: 0.0
# Searching NASA Horizons for '1937 PB'...
# Found: 1437 Diomedes (1937 PB)
# *** Mass of object: Diomedes 0.0 Radius: 0.0
# Searching NASA Horizons for '1950 SA'...
# Found: 1583 Antilochus (1950 SA)
# *** Mass of object: Antilochus 0.0 Radius: 0.0
# Searching NASA Horizons for '1957 MK'...
# Found: 1647 Menelaus (1957 MK)
# *** Mass of object: Menelaus 0.0 Radius: 0.0
# Searching NASA Horizons for '1949 SB'...
# Found: 1749 Telamon (1949 SB)
# *** Mass of object: Telamon 0.0 Radius: 0.0
# Searching NASA Horizons for '1971 EA'...
# Found: 1867 Deiphobus (1971 EA)
# *** Mass of object: Deiphobus 0.0 Radius: 0.0
# Searching NASA Horizons for '2008 P-L'...
# Found: 1868 Thersites (2008 P-L)
# *** Mass of object: Thersites 0.0 Radius: 0.0
# Searching NASA Horizons for '4596 P-L'...
# Found: 1869 Philoctetes (4596 P-L)
# *** Mass of object: Philoctetes 0.0 Radius: 0.0
# Searching NASA Horizons for '1971 FE'...
# Found: 1870 Glaukos (1971 FE)
# *** Mass of object: Glaukos 0.0 Radius: 0.0
# Searching NASA Horizons for '1971 FF'...
# Found: 1871 Astyanax (1971 FF)
# *** Mass of object: Astyanax 0.0 Radius: 0.0
# Searching NASA Horizons for '1971 FG'...
# Found: 1872 Helenos (1971 FG)
# *** Mass of object: Helenos 0.0 Radius: 0.0
# Searching NASA Horizons for '1971 FH'...
# Found: 1873 Agenor (1971 FH)
# *** Mass of object: Agenor 0.0 Radius: 0.0
# Searching NASA Horizons for '1976 UQ'...
# Found: 2146 Stentor (1976 UQ)
# *** Mass of object: Stentor 0.0 Radius: 0.0
# Searching NASA Horizons for '1976 UW'...
# Found: 2148 Epeios (1976 UW)
# *** Mass of object: Epeios 0.0 Radius: 0.0
# Searching NASA Horizons for '1977 QH1'...
# Found: 2207 Antenor (1977 QH1)
# *** Mass of object: Antenor 0.0 Radius: 0.0
# Searching NASA Horizons for '1977 TL3'...
# Found: 2223 Sarpedon (1977 TL3)
# *** Mass of object: Sarpedon 0.0 Radius: 0.0
# Searching NASA Horizons for '1979 WM'...
# Found: 2241 Alcathous (1979 WM)
# *** Mass of object: Alcathous 0.0 Radius: 0.0
# Searching NASA Horizons for '1975 WM1'...
# Found: 2260 Neoptolemus (1975 WM1)
# *** Mass of object: Neoptolemus 0.0 Radius: 0.0
# Searching NASA Horizons for '1981 AC'...
# Found: 2357 Phereclos (1981 AC)
# *** Mass of object: Phereclos 0.0 Radius: 0.0
# Searching NASA Horizons for '1977 TJ3'...
# Found: 2363 Cebriones (1977 TJ3)
# *** Mass of object: Cebriones 0.0 Radius: 0.0
# Searching NASA Horizons for '1966 BA1'...
# Found: 2456 Palamedes (1966 BA1)
# *** Mass of object: Palamedes 0.0 Radius: 0.0
# Searching NASA Horizons for '1978 TB'...
# Found: 2594 Acamas (1978 TB)
# *** Mass of object: Acamas 0.0 Radius: 0.0
# Searching NASA Horizons for '1982 BC3'...
# Found: 2674 Pandarus (1982 BC3)
# *** Mass of object: Pandarus 0.0 Radius: 0.0
# Searching NASA Horizons for '1980 GC'...
# Found: 2759 Idomeneus (1980 GC)
# *** Mass of object: Idomeneus 0.0 Radius: 0.0
# Searching NASA Horizons for '1981 LK'...
# Found: 2797 Teucer (1981 LK)
# *** Mass of object: Teucer 0.0 Radius: 0.0
# Searching NASA Horizons for '1975 QD'...
# Found: 2893 Peiroos (1975 QD)
# *** Mass of object: Peiroos 0.0 Radius: 0.0
# Searching NASA Horizons for '1981 AE1'...
# Found: 2895 Memnon (1981 AE1)
# *** Mass of object: Memnon 0.0 Radius: 0.0
# Searching NASA Horizons for '1981 JR'...
# Found: 2920 Automedon (1981 JR)
# *** Mass of object: Automedon 0.0 Radius: 0.0
# Searching NASA Horizons for '1983 PV'...
# Found: 3063 Makhaon (1983 PV)
# *** Mass of object: Makhaon 0.0 Radius: 0.0
# Searching NASA Horizons for '1978 VG6'...
# Found: 3240 Laocoon (1978 VG6)
# *** Mass of object: Laocoon 0.0 Radius: 0.0
# Searching NASA Horizons for '1984 KF'...
# Found: 3317 Paris (1984 KF)
# *** Mass of object: Paris 0.0 Radius: 0.0
# Searching NASA Horizons for '1977 DD3'...
# Found: 3391 Sinon (1977 DD3)
# *** Mass of object: Sinon 0.0 Radius: 0.0
# Searching NASA Horizons for '1984 HA1'...
# Found: 3451 Mentor (1984 HA1)
# *** Mass of object: Mentor 0.0 Radius: 0.0
# Searching NASA Horizons for '1973 UF5'...
# Found: 3540 Protesilaos (1973 UF5)
# *** Mass of object: Protesilaos 0.0 Radius: 0.0
# Searching NASA Horizons for '1973 SO'...
# Found: 3548 Eurybates (1973 SO)
# *** Mass of object: Eurybates 0.0 Radius: 0.0
# Searching NASA Horizons for '1985 TC1'...
# Found: 3564 Talthybius (1985 TC1)
# *** Mass of object: Talthybius 0.0 Radius: 0.0
# Searching NASA Horizons for '1985 VO'...
# Found: 3596 Meriones (1985 VO)
# *** Mass of object: Meriones 0.0 Radius: 0.0
# Searching NASA Horizons for '1974 FV1'...
# Found: 3708 Socus (1974 FV1)
# *** Mass of object: Socus 0.0 Radius: 0.0
# Searching NASA Horizons for '1985 TL3'...
# Found: 3709 Polypoites (1985 TL3)
# *** Mass of object: Polypoites 0.0 Radius: 0.0
# Searching NASA Horizons for '1985 TE3'...
# Found: 3793 Leonteus (1985 TE3)
# *** Mass of object: Leonteus 0.0 Radius: 0.0
# Searching NASA Horizons for '1985 TF3'...
# Found: 3794 Sthenelos (1985 TF3)
# *** Mass of object: Sthenelos 0.0 Radius: 0.0
# Searching NASA Horizons for '1985 VS'...
# Found: 3801 Thrasymedes (1985 VS)
# *** Mass of object: Thrasymedes 0.0 Radius: 0.0
# Searching NASA Horizons for '1973 SR'...
# Found: 4007 Euryalos (1973 SR)
# *** Mass of object: Euryalos 0.0 Radius: 0.0
# Searching NASA Horizons for '1986 WD'...
# Found: 4035 Thestor (1986 WD)
# *** Mass of object: Thestor 0.0 Radius: 0.0
# Searching NASA Horizons for '1985 TQ'...
# Found: 4057 Demophon (1985 TQ)
# *** Mass of object: Demophon 0.0 Radius: 0.0
# Searching NASA Horizons for '1987 YT1'...
# Found: 4060 Deipylos (1987 YT1)
# *** Mass of object: Deipylos 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 CG2'...
# Found: 4063 Euforbo (1989 CG2)
# *** Mass of object: Euforbo 0.0 Radius: 0.0
# Searching NASA Horizons for '1973 SW'...
# Found: 4068 Menestheus (1973 SW)
# *** Mass of object: Menestheus 0.0 Radius: 0.0
# Searching NASA Horizons for '1985 VK2'...
# Found: 4086 Podalirius (1985 VK2)
# *** Mass of object: Podalirius 0.0 Radius: 0.0
# Searching NASA Horizons for '1973 SM'...
# Found: 4138 Kalchas (1973 SM)
# *** Mass of object: Kalchas 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 RU'...
# Found: 4348 Poulydamas (1988 RU)
# *** Mass of object: Poulydamas 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 AK'...
# Found: 4489 Dracius (1988 AK)
# *** Mass of object: Dracius 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 CJ3'...
# Found: 4501 Eurypylos (1989 CJ3)
# *** Mass of object: Eurypylos 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 CQ1'...
# Found: 4543 Phoinix (1989 CQ1)
# *** Mass of object: Phoinix 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 PY'...
# Found: 4707 Khryses (1988 PY)
# *** Mass of object: Khryses 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 RT'...
# Found: 4708 Polydoros (1988 RT)
# *** Mass of object: Polydoros 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 TU2'...
# Found: 4709 Ennomos (1988 TU2)
# *** Mass of object: Ennomos 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 TS1'...
# Found: 4715 Medesicaste (1989 TS1)
# *** Mass of object: Medesicaste 0.0 Radius: 0.0
# Searching NASA Horizons for '4271 T-3'...
# Found: 4722 Agelaos (4271 T-3)
# *** Mass of object: Agelaos 0.0 Radius: 0.0
# Searching NASA Horizons for '5010 T-3'...
# Found: 4754 Panthoos (5010 T-3)
# *** Mass of object: Panthoos 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 PB1'...
# Found: 4791 Iphidamas (1988 PB1)
# *** Mass of object: Iphidamas 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 RK1'...
# Found: 4792 Lykaon (1988 RK1)
# *** Mass of object: Lykaon 0.0 Radius: 0.0
# Searching NASA Horizons for '1990 VH7'...
# Found: 4805 Asteropaios (1990 VH7)
# *** Mass of object: Asteropaios 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 QE'...
# Found: 4827 Dares (1988 QE)
# *** Mass of object: Dares 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 RV'...
# Found: 4828 Misenus (1988 RV)
# *** Mass of object: Misenus 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 RM1'...
# Found: 4829 Sergestus (1988 RM1)
# *** Mass of object: Sergestus 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 TU1'...
# Found: 4832 Palinurus (1988 TU1)
# *** Mass of object: Palinurus 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 AL2'...
# Found: 4833 Meges (1989 AL2)
# *** Mass of object: Meges 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 AM2'...
# Found: 4834 Thoas (1989 AM2)
# *** Mass of object: Thoas 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 BQ'...
# Found: 4835 Asaeus (1989 BQ)
# *** Mass of object: Asaeus 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 CK1'...
# Found: 4836 Medon (1989 CK1)
# *** Mass of object: Medon 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 SZ'...
# Found: 4867 Polites (1989 SZ)
# *** Mass of object: Polites 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 AN2'...
# Found: 4902 Thessandrus (1989 AN2)
# *** Mass of object: Thessandrus 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 BW1'...
# Found: 4946 Askalaphus (1988 BW1)
# *** Mass of object: Askalaphus 0.0 Radius: 0.0
# Searching NASA Horizons for '9507 P-L'...
# Found: 5012 Eurymedon (9507 P-L)
# *** Mass of object: Eurymedon 0.0 Radius: 0.0
# Searching NASA Horizons for '1985 TG3'...
# Found: 5023 Agapenor (1985 TG3)
# *** Mass of object: Agapenor 0.0 Radius: 0.0
# Searching NASA Horizons for '1986 TS6'...
# Found: 5025 Mecisteus (1986 TS6)
# *** Mass of object: Mecisteus 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 BX1'...
# Found: 5027 Androgeos (1988 BX1)
# *** Mass of object: Androgeos 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 BY1'...
# Found: 5028 Halaesus (1988 BY1)
# *** Mass of object: Halaesus 0.0 Radius: 0.0
# Searching NASA Horizons for '1973 SW1'...
# Found: 5041 Theotes (1973 SW1)
# *** Mass of object: Theotes 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 RA1'...
# Found: 5119 Imbrius (1988 RA1)
# *** Mass of object: Imbrius 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 TZ1'...
# Found: 5120 Bitias (1988 TZ1)
# *** Mass of object: Bitias 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 BL'...
# Found: 5123 Cynus (1989 BL)
# *** Mass of object: Cynus 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 CH2'...
# Found: 5126 Achaemenides (1989 CH2)
# *** Mass of object: Achaemenides 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 SC7'...
# Found: 5130 Ilioneus (1989 SC7)
# *** Mass of object: Ilioneus 0.0 Radius: 0.0
# Searching NASA Horizons for '1991 XX'...
# Found: 5144 Achates (1991 XX) (chosen from query '1991 XX')
# *** Mass of object: Achates 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 CW1'...
# /home/alfumaga2001/.local/lib/python3.8/site-packages/rebound/horizons.py:165: RuntimeWarning: Warning: Mass cannot be retrieved from NASA HORIZONS. Set to 0.
#   warnings.warn("Warning: Mass cannot be retrieved from NASA HORIZONS. Set to 0.", RuntimeWarning)
# Found: 5209 Oloosson (1989 CW1)
# *** Mass of object: Oloosson 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 RL10'...
# Found: 5233 Nastes (1988 RL10)
# *** Mass of object: Nastes 0.0 Radius: 0.0
# Searching NASA Horizons for '1973 SQ1'...
# Found: 5244 Amphilochos (1973 SQ1)
# *** Mass of object: Amphilochos 0.0 Radius: 0.0
# Searching NASA Horizons for '1986 VG1'...
# Found: 5254 Ulysses (1986 VG1)
# *** Mass of object: Ulysses 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 RS10'...
# Found: 5257 Laogonus (1988 RS10)
# *** Mass of object: Laogonus 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 AU1'...
# Found: 5258 Rhoeo (1989 AU1)
# *** Mass of object: Rhoeo 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 BB1'...
# Found: 5259 Epeigeus (1989 BB1)
# *** Mass of object: Epeigeus 0.0 Radius: 0.0
# Searching NASA Horizons for '1991 KC'...
# Found: 5264 Telephus (1991 KC)
# *** Mass of object: Telephus 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 BW'...
# Found: 5283 Pyrrhus (1989 BW)
# *** Mass of object: Pyrrhus 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 CK2'...
# Found: 5284 Orsilocus (1989 CK2)
# *** Mass of object: Orsilocus 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 EO11'...
# Found: 5285 Krethon (1989 EO11)
# *** Mass of object: Krethon 0.0 Radius: 0.0
# Searching NASA Horizons for '1990 DK'...
# Found: 5436 Eumelos (1990 DK)
# *** Mass of object: Eumelos 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 TO11'...
# Found: 5476 Mulius (1989 TO11)
# *** Mass of object: Mulius 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 TH1'...
# Found: 5511 Cloanthus (1988 TH1)
# *** Mass of object: Cloanthus 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 RF1'...
# Found: 5637 Gyas (1988 RF1)
# *** Mass of object: Gyas 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 TA3'...
# Found: 5638 Deikoon (1988 TA3)
# *** Mass of object: Deikoon 0.0 Radius: 0.0
# Searching NASA Horizons for '1990 VU1'...
# Found: 5648 Axius (1990 VU1)
# *** Mass of object: Axius 0.0 Radius: 0.0
# Searching NASA Horizons for '1992 HS3'...
# Found: 5652 Amphimachus (1992 HS3)
# *** Mass of object: Amphimachus 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 TU5'...
# Found: 5907 Rhigmus (1989 TU5)
# *** Mass of object: Rhigmus 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 RO'...
# Found: 6002 Eetion (1988 RO)
# *** Mass of object: Eetion 0.0 Radius: 0.0
# Searching NASA Horizons for '1989 DJ'...
# Found: 6090 Aulis (1989 DJ)
# *** Mass of object: Aulis 0.0 Radius: 0.0
# Searching NASA Horizons for '1988 RH12'...
# Found: 6443 Harpalion (1988 RH12)
# *** Mass of object: Harpalion 0.0 Radius: 0.0
# Searching NASA Horizons for '1986 TR6'...
# Found: 6545 Leitus (1986 TR6)
# *** Mass of object: Leitus 0.0 Radius: 0.0
# Searching NASA Horizons for '3104 T-3'...
# Found: 6997 Laomedon (3104 T-3)
# *** Mass of object: Laomedon 0.0 Radius: 0.0
# *** Current timestamp is: 2022-12-13 14:04:50.408051
# *** step: 0.001
# Integration for object number: 0 name: Sun
# Integration for object number: 1 name: Jupiter
# Integration for object number: 2 name: Achilles
# Integration for object number: 3 name: Patroclus
# Integration for object number: 4 name: Hektor
# Integration for object number: 5 name: Nestor
# Integration for object number: 6 name: Priamus
# Integration for object number: 7 name: Agamemnon
# Integration for object number: 8 name: Odysseus
# Integration for object number: 9 name: Aneas
# Integration for object number: 10 name: Anchises
# Integration for object number: 11 name: Troilus
# Integration for object number: 12 name: Ajax
# Integration for object number: 13 name: Diomedes
# Integration for object number: 14 name: Antilochus
# Integration for object number: 15 name: Menelaus
# Integration for object number: 16 name: Telamon
# Integration for object number: 17 name: Deiphobus
# Integration for object number: 18 name: Thersites
# Integration for object number: 19 name: Philoctetes
# Integration for object number: 20 name: Glaukos
# Integration for object number: 21 name: Astyanax
# Integration for object number: 22 name: Helenos
# Integration for object number: 23 name: Agenor
# Integration for object number: 24 name: Stentor
# Integration for object number: 25 name: Epeios
# Integration for object number: 26 name: Antenor
# Integration for object number: 27 name: Sarpedon
# Integration for object number: 28 name: Alcathous
# Integration for object number: 29 name: Neoptolemus
# Integration for object number: 30 name: Phereclos
# Integration for object number: 31 name: Cebriones
# Integration for object number: 32 name: Palamedes
# Integration for object number: 33 name: Acamas
# Integration for object number: 34 name: Pandarus
# Integration for object number: 35 name: Idomeneus
# Integration for object number: 36 name: Teucer
# Integration for object number: 37 name: Peiroos
# Integration for object number: 38 name: Memnon
# Integration for object number: 39 name: Automedon
# Integration for object number: 40 name: Makhaon
# Integration for object number: 41 name: Laocoon
# Integration for object number: 42 name: Paris
# Integration for object number: 43 name: Sinon
# Integration for object number: 44 name: Mentor
# Integration for object number: 45 name: Protesilaos
# Integration for object number: 46 name: Eurybates
# Integration for object number: 47 name: Talthybius
# Integration for object number: 48 name: Meriones
# Integration for object number: 49 name: Socus
# Integration for object number: 50 name: Polypoites
# Integration for object number: 51 name: Leonteus
# Integration for object number: 52 name: Sthenelos
# Integration for object number: 53 name: Thrasymedes
# Integration for object number: 54 name: Euryalos
# Integration for object number: 55 name: Thestor
# Integration for object number: 56 name: Demophon
# Integration for object number: 57 name: Deipylos
# Integration for object number: 58 name: Euforbo
# Integration for object number: 59 name: Menestheus
# Integration for object number: 60 name: Podalirius
# Integration for object number: 61 name: Kalchas
# Integration for object number: 62 name: Poulydamas
# Integration for object number: 63 name: Dracius
# Integration for object number: 64 name: Eurypylos
# Integration for object number: 65 name: Phoinix
# Integration for object number: 66 name: Khryses
# Integration for object number: 67 name: Polydoros
# Integration for object number: 68 name: Ennomos
# Integration for object number: 69 name: Medesicaste
# Integration for object number: 70 name: Agelaos
# Integration for object number: 71 name: Panthoos
# Integration for object number: 72 name: Iphidamas
# Integration for object number: 73 name: Lykaon
# Integration for object number: 74 name: Asteropaios
# Integration for object number: 75 name: Dares
# Integration for object number: 76 name: Misenus
# Integration for object number: 77 name: Sergestus
# Integration for object number: 78 name: Palinurus
# Integration for object number: 79 name: Meges
# Integration for object number: 80 name: Thoas
# Integration for object number: 81 name: Asaeus
# Integration for object number: 82 name: Medon
# Integration for object number: 83 name: Polites
# Integration for object number: 84 name: Thessandrus
# Integration for object number: 85 name: Askalaphus
# Integration for object number: 86 name: Eurymedon
# Integration for object number: 87 name: Agapenor
# Integration for object number: 88 name: Mecisteus
# Integration for object number: 89 name: Androgeos
# Integration for object number: 90 name: Halaesus
# Integration for object number: 91 name: Theotes
# Integration for object number: 92 name: Imbrius
# Integration for object number: 93 name: Bitias
# Integration for object number: 94 name: Cynus
# Integration for object number: 95 name: Achaemenides
# Integration for object number: 96 name: Ilioneus
# Integration for object number: 97 name: Achates
# Integration for object number: 98 name: Oloosson
# Integration for object number: 99 name: Nastes
# Integration for object number: 100 name: Amphilochos
# Integration for object number: 101 name: Ulysses
# Integration for object number: 102 name: Laogonus
# Integration for object number: 103 name: Rhoeo
# Integration for object number: 104 name: Epeigeus
# Integration for object number: 105 name: Telephus
# Integration for object number: 106 name: Pyrrhus
# Integration for object number: 107 name: Orsilocus
# Integration for object number: 108 name: Krethon
# Integration for object number: 109 name: Eumelos
# Integration for object number: 110 name: Mulius
# Integration for object number: 111 name: Cloanthus
# Integration for object number: 112 name: Gyas
# Integration for object number: 113 name: Deikoon
# Integration for object number: 114 name: Axius
# Integration for object number: 115 name: Amphimachus
# Integration for object number: 116 name: Rhigmus
# Integration for object number: 117 name: Eetion
# Integration for object number: 118 name: Aulis
# Integration for object number: 119 name: Harpalion
# Integration for object number: 120 name: Leitus
# Integration for object number: 121 name: Laomedon

# %% [markdown]
# ### Save status

# %%
sim.simulationarchive_snapshot(f"bin/trojan_simulation_{n_trojan_object}.bin", deletefile=True)
#sim = rebound.Simulation(f"/data/workspace_files/bin/trojan_simulation_{n_trojan_object}.bin")

# %% [markdown]
# ### Plot them !!

# %%
import matplotlib.pyplot as plt
current_time = datetime.datetime.now()
sns.set_theme()
timestamp_str = "Trojan objects at localtime: " + str(current_time)
print (f"{timestamp_str}")
fig = rebound.OrbitPlot(sim, figsize=(12,12), unitlabel="[AU]", color=True, slices=0.2, orbit_type=None, lw=1)
plt.savefig("figure/trojan_objects_orbit_2d.png", dpi=600)
# Out:
# Trojan objects at localtime: 2022-12-13 14:57:35.226032

# %% [markdown]
# ### Objects Orbit for one Jupiter year

# %%
import matplotlib.pyplot as plt

n_row = 4
n_col = 3

fig_hilda, axs = plt.subplots(n_row, n_col, figsize=(18, 18))

row = 0
Jupiter_period = 4330 # Jupiter period
N_output = 433 # number of sample 

fig_hilda.tight_layout(pad = 2.0)

time_tick = 0
for sample in range(0, (n_col * n_row) - 1):
    col = sample % n_col
    print (f"Preparing diagram # [{row}, {col}]")
    for obj in range(0, object_index):
        if obj == 0:
            axs[row, col].scatter(x_pos[obj, time_tick], y_pos[obj, time_tick], c= 'orange', marker="*")
        else:
            if obj == 1:
                axs[row, col].scatter(x_pos[obj, time_tick], y_pos[obj, time_tick], c= 'red', marker="s")
            else:
                if obj == 2:
                    axs[row, col].scatter(x_pos[obj, time_tick], y_pos[obj, time_tick], c= 'blue', marker="o")
                else:
                    axs[row, col].scatter(x_pos[obj, time_tick], y_pos[obj, time_tick], c= 'black', marker=".")
        axs[row, col].grid()
    axs[row, col].set_title(f"{time_tick/N_output * 100:.2f}% of one Jupiter year")
    axs[row, col].set_xlabel("x (AU)")
    axs[row, col].set_ylabel("y (AU)")
    time_tick = time_tick + int(N_output / 10)
    if col == (n_col - 1):
        row = row + 1

plt.savefig("figure/trojan_objects_orbit_frames.png", dpi=600)
# Out:
# Preparing diagram # [0, 0]
# Preparing diagram # [0, 1]
# Preparing diagram # [0, 2]
# Preparing diagram # [1, 0]
# Preparing diagram # [1, 1]
# Preparing diagram # [1, 2]
# Preparing diagram # [2, 0]
# Preparing diagram # [2, 1]
# Preparing diagram # [2, 2]
# Preparing diagram # [3, 0]
# Preparing diagram # [3, 1]

# %% [markdown]
# ### Plot some of them in 3D

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

n_row = 2
n_col = 2
limit_x = 6

fig_hilda_3d = plt.figure(figsize=(18, 18))
fig_hilda_3d.tight_layout(pad = 2.0)

object_slice_list = list(object_list.values())
row = 0
num_plot = 1

for sample in range(0, (n_col * n_row)):
    col = sample % n_col
    print (f"Preparing diagram # [{row}, {col}]")
    axs = fig_hilda_3d.add_subplot(n_row, n_col, num_plot, projection='3d')
    
    axs.scatter3D(x_pos[0], y_pos[0], z_pos[0], marker='.', color='yellow', s=250)
    axs.text(x_pos[0][0], y_pos[0][0], z_pos[0][0], 'Sun', size=15)
    
    axs.scatter3D(x_pos[1], y_pos[1], z_pos[1], marker='.', color='Brown', s=100)
    axs.text(x_pos[1][0], y_pos[1][0], z_pos[1][0], 'Jupiter', size=15)
    
    leg_list = ['Sun', 'Jupiter']
    random_object_index = np.random.randint(2, object_index, size=3)
    for obj in random_object_index:
        axs.scatter3D(x_pos[obj], y_pos[obj], z_pos[obj], marker='.', s=100)
        axs.text(x_pos[obj][0], y_pos[obj][0], z_pos[obj][0], 'O', size=12)
        leg_list.append(object_slice_list[obj])
    axs.grid()
    axs.set_xlabel('x (AU)')
    axs.set_ylabel('y (AU)')
    axs.set_zlabel('z (AU)')
    axs.set_xlim(-limit_x, limit_x)
    axs.set_ylim(-limit_x, limit_x)
    axs.set_zlim(-2, 1.5)
    axs.legend(leg_list, loc='upper left')

    axs.set_title(f"3D orbit for Trojan objects")
    if col == (n_col - 1):
        row = row + 1
    num_plot = num_plot + 1

plt.savefig("figure/trojan_objects_orbit_random_3d.png", dpi=600)
# Out:
# Preparing diagram # [0, 0]
# Preparing diagram # [0, 1]
# Preparing diagram # [1, 0]
# Preparing diagram # [1, 1]

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15, 35))

ax = plt.axes(projection='3d')

ax.scatter3D(x_pos[0], y_pos[0], z_pos[0], marker='.', color='yellow', s=250)
ax.text(x_pos[0][0], y_pos[0][0], z_pos[0][0], 'Sun', size=15)

ax.scatter3D(x_pos[1], y_pos[1], z_pos[1], marker='.', color='Brown', s=100)
ax.text(x_pos[1][0], y_pos[1][0], z_pos[1][0], 'Jupiter', size=15)

object_index = 0
for jupiter_object, jupiter_name in object_list.items():
    if (object_index == 0) or (object_index == 1):
        object_index = object_index + 1
        continue
    ax.scatter3D(x_pos[object_index], y_pos[object_index], z_pos[object_index], marker='.', s=100)
    ax.text(x_pos[object_index][0], y_pos[object_index][0], z_pos[object_index][0], 'O', size=12)
    if object_index == 5:
        break
    object_index = object_index + 1

ax.set_xlabel('x (AU)')
ax.set_ylabel('y (AU)')
ax.set_zlabel('z (AU)')
limit_x = 6
ax.set_xlim(-limit_x, limit_x); ax.set_ylim(-limit_x, limit_x); ax.set_zlim(-2, 1.5)
ax.legend(object_list.values(), loc='upper left')

plt.savefig("figure/trojan_objects_orbit_3d.png", dpi=600)

# %% [markdown]
# ### Resonance between Trojan objects and Jupiter

# %%
# %matplotlib inline

fig = plt.figure(figsize=(20, 10))

object_index = 0
distance = {}
for jupiter_object, jupiter_name in object_list.items():
    if object_index == 0:
        object_index = object_index + 1
        continue
    distance [jupiter_name] = np.zeros((1, N_output)) 
    distance [jupiter_name] = np.sqrt(np.square(x_pos[0]-x_pos[object_index]) + np.square(y_pos[0]-y_pos[object_index]) + np.square(z_pos[0]-z_pos[object_index]))
    object_index = object_index + 1
    plt.plot(distance [jupiter_name], label = jupiter_name, marker=".")
    plt.grid()
    if object_index > 5:
        break

plt.grid()
plt.title ('Periodicity of Trojan objects')
plt.xlabel("Time")
plt.ylabel("Distance (AU)")
plt.legend()

plt.savefig("figure/trojan_objects_resonance.png", dpi=600)

# %% [markdown]
# ### Save DF

# %%
MPC_Jupyter_no_outliers_Trojan.to_pickle("bin/df_trojan.pkl")

# %%
MPC_Jupyter_no_outliers_Trojan = pd.read_pickle("bin/df_trojan.pkl")

# %% [markdown]
# ### Estimate mass of objects
# - (formula) http://www.physics.sfasu.edu/astro/asteroids/sizemagnitude.html
# - (table) https://www.minorplanetcenter.net/iau/Sizes.html
# - (formula) https://cneos.jpl.nasa.gov/tools/ast_size_est.html

# %%
MPC_Jupyter_no_outliers_Trojan.head(5)
# Out:
#         H     G  Arc_years       Name Principal_desig            Other_desigs  \
# 587  8.27  0.15  1906-2022   Achilles         A906 DN                     NaN
# 616  8.18  0.15  1906-2022  Patroclus         A906 UL  ['1941 XC', '1962 NB']
# 623  7.45  0.15  1907-2022     Hektor         A907 CF             ['1948 VD']
# 658  8.72  0.15  1908-2022     Nestor         A908 FE             ['A914 WF']
# 883  8.70  0.15  1917-2022    Priamus         A917 SU  ['1929 XX', '1938 KE']
#
#              M         i         e         a  Orbital_period         q  \
# 587  337.91683  10.31992  0.148139  5.209205       11.889323  4.437519
# 616  303.03188  22.06206  0.139868  5.210104       11.892403  4.481378
# 623  271.39649  18.15500  0.022738  5.268938       12.094409  5.149131
# 658   81.65525   4.52244  0.116972  5.167175       11.745724  4.562762
# 883   30.93289   8.90872  0.125238  5.195633       11.842888  4.544944
#
#             Q Orbit_type Discover Last_Obs
# 587  5.980890     Trojan     1906     2022
# 616  5.938830     Trojan     1906     2022
# 623  5.388745     Trojan     1907     2022
# 658  5.771589     Trojan     1908     2022
# 883  5.846321     Trojan     1917     2022

# %% [markdown]
# ### Diameter vs albedo data for Trojan objects

# %% [markdown]
# - Read data from  https://sbn.psi.edu/pds/resource/neowisediam.html and preprocess them

# %%
neo_wise_df = pd.read_csv("data/neowise_trojans.csv")
neo_wise_df.drop(['Slope_param','Mean_JD','N_W1','N_W2','N_W3', 'N_W4','Fit_code','IR_albedo','IR_albedo_err','Beaming_param','Beaming_param_err','Stacked_flag','Reference','Notes'], axis=1, inplace=True)
neo_wise_df['MPC_packed_name'] = neo_wise_df['MPC_packed_name'].str.strip()
neo_wise_df['Prov_design'] = neo_wise_df['Prov_design'].str.strip()
#neo_wise_df = neo_wise_df.apply(lambda r: r[~neo_wise_df['Prov_design'].isin(['-'])])
neo_wise_df.head(10)
# Out:
#    Asteroid_number Prov_design MPC_packed_name  Absolute_mag  Diameter  \
# 0              588           -           00588          8.47   130.099
# 1              617           -           00617          8.19   140.362
# 2              624           -           00624          7.20   147.369
# 3              659           -           00659          8.99   112.320
# 4              884           -           00884          8.98   101.093
# 5              911           -           00911          7.89   131.038
# 6             1143           -           01143          8.57   114.624
# 7             1172           -           01172          8.33   118.020
# 8             1173           -           01173          8.89    99.549
# 9             1208           -           01208          9.08   100.477
#
#    Diameter_err  V_albedo  V_albedo_err
# 0         0.554     0.043         0.006
# 1         0.868     0.047         0.003
# 2         2.325     0.107         0.011
# 3         1.850     0.035         0.008
# 4         0.539     0.044         0.002
# 5         1.195     0.072         0.010
# 6         0.592     0.050         0.007
# 7         0.806     0.059         0.006
# 8         0.846     0.050         0.009
# 9         1.097     0.041         0.006

# %%
neo_wise_df.describe()
# Out:
#        Asteroid_number  Absolute_mag     Diameter  Diameter_err     V_albedo  \
# count      1860.000000   1860.000000  1860.000000   1860.000000  1860.000000
# mean     158368.335484     12.257715    20.839765      0.978590     0.074253
# std      127847.516611      1.136428    16.059590      0.594967     0.025880
# min           0.000000      7.200000     3.943000      0.100000     0.025000
# 25%       31812.000000     11.600000    12.516000      0.643750     0.056000
# 50%      156265.000000     12.500000    15.553000      0.870500     0.070000
# 75%      264141.750000     13.100000    22.079000      1.177500     0.087000
# max      514762.000000     15.600000   147.369000      6.824000     0.200000
#
#        V_albedo_err
# count   1860.000000
# mean       0.017230
# std        0.008994
# min        0.002000
# 25%        0.011000
# 50%        0.015000
# 75%        0.021000
# max        0.093000

# %%
import matplotlib.pyplot as plt
fig, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(14, 6), dpi=300)

fig.suptitle('Trojan objects: Scatter diagrams from NEOWISE data', fontsize=16)

ax1.set_title('Magnitude vs Diameter', fontsize=13)
x = ax1.scatter(neo_wise_df ['Absolute_mag'], neo_wise_df ['Diameter'], color='r', marker=".", label="Trojan objects")
ax1.set_xlabel("Absolute magnitude", fontsize=13)
ax1.set_ylabel("Diameter (Km)", fontsize=13)
ax1.legend()
ax1.grid()

ax2.set_title('Visual albedo vs Diameter', fontsize=13)
ax2.set_xscale('log')
y = ax2.scatter(neo_wise_df ['Diameter'], neo_wise_df ['V_albedo'], color='b', marker=".", label="Trojan objects")
ax2.grid()
ax2.set_xlabel("Visual albedo", fontsize=13)
ax2.set_ylabel("Diameter (Km)", fontsize=13)
ax2.legend()

fig.savefig('figure/trojan_objects_magnitude_albedo_diameter.png', dpi=600)

# %%
import folium
from geopy.geocoders import Nominatim

locator = Nominatim(user_agent='myGeocoder')
location = locator.geocode('Via Bestetti 8, Villasanta')

color = [ "red", "blue", "green", "yellow", "purple", 'black', 'white','orange']

stat = pd.DataFrame({'Stat': neo_wise_df['Diameter'].describe(), 'color': color, 'gav_lat': location.latitude, 'gav_lon': location.longitude})
stat = stat.drop('count')
stat = stat.drop('std')

m = folium.Map(location=(stat['gav_lat'].mean(), stat['gav_lon'].mean()), zoom_start=8, title="Object size", Stamen='Toner')

for lat, lon, diam, color in zip(stat['gav_lat'], 
                                 stat['gav_lon'], 
                                 stat['Stat'], 
                                 stat['color']):
    radius = int(diam * 1000 / 2)    
    label = folium.Popup('Trojan object diameter: ' + str(diam) + " Km", parse_html=True)
    folium.Circle(location = (lat, lon),
                  popup = label,
                  radius = radius,
                  color = color,
                  fill=True,
                  fill_opacity=0.1).add_to(m)

m.save('figure/trojan_objects_size_on_terrain_folium.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90ab4e8eb731c0e0c9a912ed4050eb0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90ab4e8eb731c0e0c9a912ed4050eb0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_90ab4e8eb731c0e0c9a912ed4050eb0c = L.map(
#                 &quot;map_90ab4e8eb731c0e0c9a912ed4050eb0c&quot;,
#                 {
#                     center: [45.6033261, 9.3001047],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     title: &quot;Object size&quot;,
#                     Stamen: &quot;Toner&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_da5825e292ee24add3aa29597e39d201 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_90ab4e8eb731c0e0c9a912ed4050eb0c);
#
#
#             var circle_cd8e1464714e58638da974844124937f = L.circle(
#                 [45.6033261, 9.3001047],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10419, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_90ab4e8eb731c0e0c9a912ed4050eb0c);
#
#
#         var popup_75a1c64909bb00a4218f6f5f2a5234fe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ce7f50b28372a7466ac074ba187c0178 = $(`&lt;div id=&quot;html_ce7f50b28372a7466ac074ba187c0178&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Trojan object diameter: 20.839765053763443 Km&lt;/div&gt;`)[0];
#                 popup_75a1c64909bb00a4218f6f5f2a5234fe.setContent(html_ce7f50b28372a7466ac074ba187c0178);
#
#
#
#         circle_cd8e1464714e58638da974844124937f.bindPopup(popup_75a1c64909bb00a4218f6f5f2a5234fe)
#         ;
#
#
#
#
#             var circle_7f2a186ca14b7c20e75a376a85704d26 = L.circle(
#                 [45.6033261, 9.3001047],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1971, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_90ab4e8eb731c0e0c9a912ed4050eb0c);
#
#
#         var popup_79b43d276a570a5373088d10b505f278 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1041832213ec3ed06fa09ae5b6156f09 = $(`&lt;div id=&quot;html_1041832213ec3ed06fa09ae5b6156f09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Trojan object diameter: 3.943 Km&lt;/div&gt;`)[0];
#                 popup_79b43d276a570a5373088d10b505f278.setContent(html_1041832213ec3ed06fa09ae5b6156f09);
#
#
#
#         circle_7f2a186ca14b7c20e75a376a85704d26.bindPopup(popup_79b43d276a570a5373088d10b505f278)
#         ;
#
#
#
#
#             var circle_ee4407fb5f07a3451ac1b8c30651f5e4 = L.circle(
#                 [45.6033261, 9.3001047],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6258, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_90ab4e8eb731c0e0c9a912ed4050eb0c);
#
#
#         var popup_d0823c406a0e433837b75023d788754f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb803b0e99e3f95fe85933999e22b98d = $(`&lt;div id=&quot;html_fb803b0e99e3f95fe85933999e22b98d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Trojan object diameter: 12.516 Km&lt;/div&gt;`)[0];
#                 popup_d0823c406a0e433837b75023d788754f.setContent(html_fb803b0e99e3f95fe85933999e22b98d);
#
#
#
#         circle_ee4407fb5f07a3451ac1b8c30651f5e4.bindPopup(popup_d0823c406a0e433837b75023d788754f)
#         ;
#
#
#
#
#             var circle_983bef348cd94de8867f8bb67aca5a94 = L.circle(
#                 [45.6033261, 9.3001047],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &qu

# %%
import matplotlib.pyplot as plt
fig, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(14, 6), dpi=300)

fig.suptitle('Trojan objects: histograms from NEOWISE data', fontsize=16)

ax1.set_title('Diameter distribution', fontsize=13)
ax1.hist(neo_wise_df['Diameter'], bins='auto', color='red')
ax1.grid()
ax1.set_xlabel("Number of objects", fontsize=13)
ax1.set_ylabel("Diameter (Km)", fontsize=13)
ax1.grid()

ax2.set_title('Visual albedo distribution', fontsize=13)
ax2.hist(neo_wise_df['V_albedo'], bins='auto')
ax2.grid()
ax2.set_xlabel("Number of objects", fontsize=13)
ax2.set_ylabel("Visual albedo", fontsize=13)
ax2.grid()

plt.savefig("figure/trojan_objects_albedo.png", dpi=600)

# %% [markdown]
# ## Bibliography

# %% [markdown]
# - https://rebound.readthedocs.io/en/latest/ipython_examples/Churyumov-Gerasimenko/
# - https://rebound.readthedocs.io/en/latest/ipython_examples/WHFast/
# - https://rebound.readthedocs.io/en/latest/integrators/
# - https://rebound.readthedocs.io/en/latest/simulationarchive/#reading-simulation-archives
# - https://rebound.readthedocs.io/en/latest/ipython_examples/Testparticles/
# - https://rebound.readthedocs.io/en/latest/units/
# - https://notebook.community/dtamayo/rebound/ipython_examples/OrbitPlot
# - https://astroquery.readthedocs.io/en/latest/jplsbdb/jplsbdb.html
